# %%
def mask_score(cm_score):
    positive_or_zero_mask = cm_score >= 0
    negative_mask = cm_score < 0
    cm_score[positive_or_zero_mask] = 1
    cm_score[negative_mask] = 0
    return cm_score

# %%
# Image Method

import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset, Dataset
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import spearmanr
from tqdm import tqdm
from utils import CaptionGenerator

from utils.dataset import get_dataset
from utils.model_utils import load_model, get_text_embeddings, get_image_embeddings
import os
import glob
from PIL import Image

# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"
model_name = "openai/clip-vit-base-patch32"

datasets_info = [
    {"name": "NWPU-RESISC45", "template": "a satellite photo containing {}."},
    {"name": "Stanford_dogs", "template": "a photo of {}, a type of dog."},
    {"name": "CUB_200_2011", "template": "a photo of {}, a type of bird."},
    {"name": "Flower102", "template": "a photo of {}, a type of flower."},
]

class PseudoImageDataset(Dataset):
    def __init__(self, image_folder, class_names, transform=None):
        self.image_paths = []
        self.labels = []
        self.transform = transform
        self.class_names = class_names

        # Store class_names in a set for faster lookup
        class_name_set = set(class_names)

        for image_path in glob.glob(os.path.join(image_folder, '*.png')):
            filename = os.path.basename(image_path)
            class_name = filename.split('-')[0].replace('_', ' ')
            if class_name in class_name_set:
                self.image_paths.append(image_path)
                self.labels.append(class_name)

        # Convert labels to indices
        self.labels = [class_names.index(label) for label in self.labels]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        label = self.labels[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

def get_image_loader(dataset, class_indices, batch_size, shuffle=False):
    if hasattr(dataset, 'targets'):
        selected_indices = [i for i, label in enumerate(dataset.targets) if label in class_indices]
    else:
        selected_indices = [i for i, (_, label) in enumerate(dataset.imgs) if label in class_indices]
    selected_dataset = Subset(dataset, selected_indices)

    # Ensure no transform or compatible transform is applied
    selected_dataset.dataset.transform = None

    loader = DataLoader(
        selected_dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        collate_fn=lambda batch: (list(zip(*batch))[0], list(zip(*batch))[1])
    )
    return loader

def pairwise_difference(a, b):
  """
  Computes pairwise difference between rows of two matrices.

  Args:
    a: NumPy array of shape (N_a, D)
    b: NumPy array of shape (N_b, D)

  Returns:
    NumPy array of shape (N_a, N_b, D) containing pairwise differences.
  """
  return a[:, np.newaxis, :] - b[np.newaxis, :, :]

def run_experiment(dataset_name, template, use_pseudo_data):
    # 1. Load dataset (test split)
    dataset = get_dataset(dataset_name, data_root='data', split='test')
    class_names = dataset.classes
    num_classes = len(class_names)

    if use_pseudo_data:
        PSEUDO_IMAGES_FOLDER = f'pseudo_images/{dataset_name}'
        pseudo_dataset = PseudoImageDataset(
            image_folder=PSEUDO_IMAGES_FOLDER,
            class_names=class_names,
            transform=None
        )
        dataloader = DataLoader(
            pseudo_dataset,
            batch_size=64,
            shuffle=False,
            pin_memory=True,
            collate_fn=lambda batch: (list(zip(*batch))[0], list(zip(*batch))[1])
        )
    else:
        selected_class_indices = list(range(num_classes))
        dataloader = get_image_loader(dataset, selected_class_indices, 64, shuffle=False)

    # 2. Load model
    model_info = load_model(model_name, device=device)

    # 3. Create captions and compute text embeddings
    captions = [template.format(c) for c in class_names]
    text_embeddings = get_text_embeddings(captions, model_info, device, batch_size=64)

    # optional: create alternative captions and compute text embeddings
    # Initialize CaptionGenerator and generate alternative captions
    capGenerator = CaptionGenerator(dataset_name=dataset_name, class_names=class_names, num_captions=40)

    alter_caption_list = []
    labels = []
    for i,class_name in tqdm(enumerate(class_names), desc="Generating Alternative Captions"):
        alter_captions = capGenerator.get_alternative_captions(class_name)
        alter_caption_list.extend(alter_captions)
        labels.extend([i] * len(alter_captions))
    labels = np.array(labels)
    # Compute text embeddings for alternative captions
    alter_text_embeddings = get_text_embeddings(alter_caption_list, model_info, device, batch_size=64)
    alter_text_embeddings = alter_text_embeddings / np.linalg.norm(alter_text_embeddings, axis=1, keepdims=True)

    # 4. Compute image embeddings
    image_embeddings, all_targets = get_image_embeddings(dataloader, model_info, device)
    all_targets = np.array(all_targets)

    # Normalize embeddings
    image_embeddings = image_embeddings / np.linalg.norm(image_embeddings, axis=1, keepdims=True)
    text_embeddings = text_embeddings / np.linalg.norm(text_embeddings, axis=1, keepdims=True)

    # img shape: (N_img, D), text shape: (N_text, D)

    # 5. Compute similarities and predictions
    temperature = 0.01
    similarities = np.matmul(image_embeddings, text_embeddings.T) / temperature
    probs = np.exp(similarities) / np.sum(np.exp(similarities), axis=1, keepdims=True)

    preds = np.argmax(probs, axis=1)
    confidences = np.max(probs, axis=1)

    predicted_cm_scores = []
    # do some class-wise operations
    for c in range(num_classes):
        # Select rows of image_embeddings where the target is class c
        c_embeddings = image_embeddings[all_targets == c] # shape (N_c, D)

        other_class_text_embeddings = np.concatenate([text_embeddings[i:i+1] for i in range(num_classes) if i != c], axis=0) # shape (N_t-1, D)
        text_diff = pairwise_difference(text_embeddings[c:c+1], other_class_text_embeddings) # shape (1, N_t-1, D)
        
        c_embeddings = c_embeddings / np.linalg.norm(c_embeddings, axis=-1, keepdims=True)
        text_diff = text_diff / np.linalg.norm(text_diff, axis=-1, keepdims=True)

        cm_scores = np.einsum('cd, td -> ct', c_embeddings, text_diff[0]) # shape (N_c, N_t-1)
        
        cm_score = np.min(cm_scores, axis=-1) # shape (N_c, 1)
        # # cm_score = cm_score / (1 + cm_score) # shape (N_c, 1)
        
        def mask_score(cm_score):
            positive_or_zero_mask = cm_score >= 0
            negative_mask = cm_score < 0
            cm_score[positive_or_zero_mask] = 1
            cm_score[negative_mask] = 0
            return cm_score

        cm_score = mask_score(cm_score)
        cm_score = np.mean(cm_score, axis=0) # shape (1,)


        # use text_cm_scores as weights
        c_alter_text_embeddings = alter_text_embeddings[labels == c]
        cm_text_scores = np.einsum('cd, td -> ct', c_embeddings, c_alter_text_embeddings) # shape (N_c, N_t)
        cm_text_scores = np.min(cm_text_scores, axis=-1) # shape (N_c, 1)
        cm_text_scores = np.mean(cm_text_scores, axis=0) # shape (1,)
        if c < 5:
            print(f"Class {c}, {class_names[c]}: {cm_score}, {cm_text_scores}")
        cm_score = cm_score * cm_text_scores
        if np.isnan(cm_score):
            print(f"Class {c}, {class_names[c]} has NaN cm_score")
            cm_score = 0.0
        predicted_cm_scores.append(cm_score)

    # Compute class-wise actual and predicted accuracies
    actual_accuracies = []
    # predicted_accuracies = []
    for c in range(num_classes):
        cur_class_indices = (all_targets == c)
        cur_class_pred = preds[cur_class_indices]
        cur_class_accuracy = (cur_class_pred == c).mean()

        if np.isnan(cur_class_accuracy):
            print(f"Class {c}, {class_names[c]} has NaN accuracy")
            cur_class_accuracy = 0.0
        # predicted_cur_class_indices = (preds == c)
        # predicted_confidences = confidences[predicted_cur_class_indices]
        # predicted_acc = predicted_confidences.mean() if predicted_confidences.size > 0 else np.nan

        actual_accuracies.append(cur_class_accuracy)
        # predicted_accuracies.append(predicted_acc if not np.isnan(predicted_acc) else 0.0)
            
    # Compute Spearman correlation
    spearman_corr = spearmanr(np.array(actual_accuracies), predicted_cm_scores )# np.array(predicted_accuracies))

    # Return data for plotting outside
    return np.array(actual_accuracies), np.array(predicted_cm_scores), spearman_corr

# Now we call run_experiment for pseudo and real data and plot them together
for dinfo in datasets_info:
    actual_pseudo, predicted_pseudo, spearman_pseudo = run_experiment(dinfo["name"], dinfo["template"], use_pseudo_data=True)
    actual_real, predicted_real, spearman_real = run_experiment(dinfo["name"], dinfo["template"], use_pseudo_data=False)

    # Recompute pseudo Spearman correlation using actual_real for the y-values
    pseudo_spearman_corr = spearmanr(actual_real, predicted_pseudo)

    # Create a single plot for both pseudo and real
    fig, ax = plt.subplots(figsize=(8,8))
    # For pseudo, use actual_real as y-axis
    ax.scatter(predicted_pseudo, actual_real, color='tab:orange', label='Pseudo Images', alpha=0.5)
    ax.scatter(predicted_real, actual_real, color='tab:blue', label='Real Images', alpha=0.5)

    ax.set_xlabel("Predicted Accuracy (Confidence)")
    ax.set_ylabel("Actual Accuracy (Real Data)")
    pseudo_corr_str = f"{pseudo_spearman_corr.correlation:.2f}" if pseudo_spearman_corr.correlation is not None else "N/A"
    real_corr_str = f"{spearman_real.correlation:.2f}" if spearman_real.correlation is not None else "N/A"
    ax.set_title(f"Calibration Approach: {dinfo['name']}\nSpearman (Pseudo vs Real Accuracy): {pseudo_corr_str}, Spearman (Real vs Real Accuracy): {real_corr_str}")
    print(f"Calibration Approach: {dinfo['name']}\nSpearman (Pseudo vs Real Accuracy): {pseudo_corr_str}, Spearman (Real vs Real Accuracy): {real_corr_str}")
    ax.grid(True)
    # ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.legend()

    # Save the figure
    plot_filename = f"figures/{dinfo['name']}_CM_softmax.png"
    plt.savefig(plot_filename)
    plt.close(fig)
# Out:
# Processed batch 1/1
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45_global_traits.json
# Using OpenAI model: gpt-4o-mini-2024-07-18
# Configured to generate 40 captions.
# Meta Prompt: You are an AI assistant that generates creative and diverse image captions suitable for use with image generation models like DALL-E. Given a subject, provide 40 distinct, diverse and descriptive captions, considering the following global taxonomical traits when generating captions: ['human-made structure', 'natural landscape', 'water body', 'recreational area', 'transportation hub', 'residential zone', 'industrial zone', 'agricultural area', 'sports facility', 'ecological setting', 'urban environment', 'natural feature', 'seasonal variations', 'geographical formations', 'climatic zone'].
# Generating Alternative Captions: 45it [00:00, 1576.02it/s]
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\airplane.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\airport.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\baseball_diamond.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\basketball_court.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\beach.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\bridge.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\chaparral.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\church.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\circular_farmland.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\cloud.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\commercial_area.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\dense_residential.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\desert.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\forest.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\freeway.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\golf_course.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\ground_track_field.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\harbor.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\industrial_area.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\intersection.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\island.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\lake.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\meadow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\medium_residential.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\mobile_home_park.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\mountain.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\overpass.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\palace.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\parking_lot.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\railway.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\railway_station.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\rectangular_farmland.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\river.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\roundabout.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\runway.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\sea_ice.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\ship.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\snowberg.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\sparse_residential.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\stadium.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\storage_tank.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\tennis_court.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\terrace.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\thermal_power_station.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\wetland.json
# Processed batch 1/28
# Processed batch 2/28
# Processed batch 3/28
# Processed batch 4/28
# Processed batch 5/28
# Processed batch 6/28
# Processed batch 7/28
# Processed batch 8/28
# Processed batch 9/28
# Processed batch 10/28
# Processed batch 11/28
# Processed batch 12/28
# Processed batch 13/28
# Processed batch 14/28
# Processed batch 15/28
# Processed batch 16/28
# Processed batch 17/28
# Processed batch 18/28
# Processed batch 19/28
# Processed batch 20/28
# Processed batch 21/28
# Processed batch 22/28
# Processed batch 23/28
# Processed batch 24/28
# Processed batch 25/28
# Processed batch 26/28
# Processed batch 27/28
# Processed batch 28/28
# Processing Images: 100%|██████████| 25/25 [00:21<00:00,  1.19it/s]
# Class 0, airplane: 0.34375, 0.14402268826961517
# Class 1, airport: 0.2857142984867096, 0.12461353093385696
# Class 2, baseball diamond: 0.8125, 0.20280376076698303
# Class 3, basketball court: 0.7058823704719543, 0.1855473816394806
# Class 4, beach: 0.9428571462631226, 0.14640764892101288
# Processed batch 1/1
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45_global_traits.json
# Using OpenAI model: gpt-4o-mini-2024-07-18
# Configured to generate 40 captions.
# Meta Prompt: You are an AI assistant that generates creative and diverse image captions suitable for use with image generation models like DALL-E. Given a subject, provide 40 distinct, diverse and descriptive captions, considering the following global taxonomical traits when generating captions: ['human-made structure', 'natural landscape', 'water body', 'recreational area', 'transportation hub', 'residential zone', 'industrial zone', 'agricultural area', 'sports facility', 'ecological setting', 'urban environment', 'natural feature', 'seasonal variations', 'geographical formations', 'climatic zone'].
# Generating Alternative Captions: 45it [00:00, 3214.90it/s]
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\airplane.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\airport.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\baseball_diamond.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\basketball_court.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\beach.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\bridge.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\chaparral.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\church.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\circular_farmland.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\cloud.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\commercial_area.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\dense_residential.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\desert.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\forest.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\freeway.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\golf_course.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\ground_track_field.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\harbor.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\industrial_area.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\intersection.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\island.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\lake.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\meadow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\medium_residential.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\mobile_home_park.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\mountain.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\overpass.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\palace.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\parking_lot.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\railway.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\railway_station.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\rectangular_farmland.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\river.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\roundabout.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\runway.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\sea_ice.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\ship.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\snowberg.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\sparse_residential.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\stadium.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\storage_tank.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\tennis_court.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\terrace.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\thermal_power_station.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\NWPU-RESISC45\40\wetland.json
# Processed batch 1/28
# Processed batch 2/28
# Processed batch 3/28
# Processed batch 4/28
# Processed batch 5/28
# Processed batch 6/28
# Processed batch 7/28
# Processed batch 8/28
# Processed batch 9/28
# Processed batch 10/28
# Processed batch 11/28
# Processed batch 12/28
# Processed batch 13/28
# Processed batch 14/28
# Processed batch 15/28
# Processed batch 16/28
# Processed batch 17/28
# Processed batch 18/28
# Processed batch 19/28
# Processed batch 20/28
# Processed batch 21/28
# Processed batch 22/28
# Processed batch 23/28
# Processed batch 24/28
# Processed batch 25/28
# Processed batch 26/28
# Processed batch 27/28
# Processed batch 28/28
# Processing Images: 100%|██████████| 493/493 [04:39<00:00,  1.77it/s]
# Class 0, airplane: 0.5099999904632568, 0.13204503059387207
# Class 1, airport: 0.7128571271896362, 0.14218279719352722
# Class 2, baseball diamond: 0.7885714173316956, 0.1921466886997223
# Class 3, basketball court: 0.6785714030265808, 0.15609660744667053
# Class 4, beach: 0.8642857074737549, 0.1109732836484909
# Calibration Approach: NWPU-RESISC45
# Spearman (Pseudo vs Real Accuracy): 0.60, Spearman (Real vs Real Accuracy): 0.96
# Processed batch 1/2
# Processed batch 2/2
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs_global_traits.json
# Using OpenAI model: gpt-4o-mini-2024-07-18
# Configured to generate 40 captions.
# Meta Prompt: You are an AI assistant that generates creative and diverse image captions suitable for use with image generation models like DALL-E. Given a subject, provide 40 distinct, diverse and descriptive captions, considering the following global taxonomical traits when generating captions: ['Size variations (toy, miniature, standard, giant)', 'Coat types (short, long, curly, wiry)', 'Head shape (flat, rounded, elongated)', 'Ear shape (standing, floppy, semi-erect)', 'Tail types (curled, straight, docked)', 'Color patterns (solid, spotted, brindle, merle)', 'Body structure (muscular, slender, stocky)', 'Facial features (snout length, eye shape)', 'Temperament traits (playful, protective, loyal)', 'Working abilities (herding, hunting, guarding)'].
# Generating Alternative Captions: 120it [00:00, 1646.61it/s]
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Chihuahua.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Japanese_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Maltese_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Pekinese.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Shih_Tzu.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Blenheim_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\papillon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\toy_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Rhodesian_ridgeback.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Afghan_hound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\basset.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\beagle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\bloodhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\bluetick.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\black_and_tan_coonhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Walker_hound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\English_foxhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\redbone.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\borzoi.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_wolfhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Italian_greyhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\whippet.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Ibizan_hound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Norwegian_elkhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\otterhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Saluki.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Scottish_deerhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Weimaraner.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Staffordshire_bullterrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\American_Staffordshire_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Bedlington_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Border_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Kerry_blue_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Norfolk_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Norwich_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Yorkshire_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\wire_haired_fox_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Lakeland_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Sealyham_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Airedale.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\cairn.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Australian_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Dandie_Dinmont.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Boston_bull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\miniature_schnauzer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\giant_schnauzer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\standard_schnauzer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Scotch_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Tibetan_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\silky_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\soft_coated_wheaten_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\West_Highland_white_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Lhasa.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\flat_coated_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\curly_coated_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\golden_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Labrador_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Chesapeake_Bay_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\German_short_haired_pointer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\vizsla.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\English_setter.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_setter.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Gordon_setter.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Brittany_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\clumber.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\English_springer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Welsh_springer_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\cocker_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Sussex_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_water_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\kuvasz.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\schipperke.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\groenendael.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\malinois.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\briard.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\kelpie.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\komondor.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Old_English_sheepdog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Shetland_sheepdog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\collie.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Border_collie.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Bouvier_des_Flandres.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Rottweiler.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\German_shepherd.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Doberman.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\miniature_pinscher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Greater_Swiss_Mountain_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Bernese_mountain_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Appenzeller.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\EntleBucher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\boxer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\bull_mastiff.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Tibetan_mastiff.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\French_bulldog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Great_Dane.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Saint_Bernard.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Eskimo_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\malamute.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Siberian_husky.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\affenpinscher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\basenji.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\pug.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Leonberg.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Newfoundland.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Great_Pyrenees.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Samoyed.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Pomeranian.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\chow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\keeshond.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Brabancon_griffon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Pembroke.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Cardigan.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\toy_poodle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\miniature_poodle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\standard_poodle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Mexican_hairless.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\dingo.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\dhole.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\African_hunting_dog.json
# Processed batch 1/69
# Processed batch 2/69
# Processed batch 3/69
# Processed batch 4/69
# Processed batch 5/69
# Processed batch 6/69
# Processed batch 7/69
# Processed batch 8/69
# Processed batch 9/69
# Processed batch 10/69
# Processed batch 11/69
# Processed batch 12/69
# Processed batch 13/69
# Processed batch 14/69
# Processed batch 15/69
# Processed batch 16/69
# Processed batch 17/69
# Processed batch 18/69
# Processed batch 19/69
# Processed batch 20/69
# Processed batch 21/69
# Processed batch 22/69
# Processed batch 23/69
# Processed batch 24/69
# Processed batch 25/69
# Processed batch 26/69
# Processed batch 27/69
# Processed batch 28/69
# Processed batch 29/69
# Processed batch 30/69
# Processed batch 31/69
# Processed batch 32/69
# Processed batch 33/69
# Processed batch 34/69
# Processed batch 35/69
# Processed batch 36/69
# Processed batch 37/69
# Processed batch 38/69
# Processed batch 39/69
# Processed batch 40/69
# Processed batch 41/69
# Processed batch 42/69
# Processed batch 43/69
# Processed batch 44/69
# Processed batch 45/69
# Processed batch 46/69
# Processed batch 47/69
# Processed batch 48/69
# Processed batch 49/69
# Processed batch 50/69
# Processed batch 51/69
# Processed batch 52/69
# Processed batch 53/69
# Processed batch 54/69
# Processed batch 55/69
# Processed batch 56/69
# Processed batch 57/69
# Processed batch 58/69
# Processed batch 59/69
# Processed batch 60/69
# Processed batch 61/69
# Processed batch 62/69
# Processed batch 63/69
# Processed batch 64/69
# Processed batch 65/69
# Processed batch 66/69
# Processed batch 67/69
# Processed batch 68/69
# Processed batch 69/69
# Processing Images: 100%|██████████| 59/59 [00:55<00:00,  1.06it/s]
# Class 0, Chihuahua: 0.6774193644523621, 0.20342130959033966
# Class 1, Japanese spaniel: 0.6774193644523621, 0.22346416115760803
# Class 2, Maltese dog: 0.6774193644523621, 0.2321224957704544
# Class 3, Pekinese: 1.0, 0.26246076822280884
# Class 4, Shih Tzu: 0.9677419066429138, 0.239768847823143
# Processed batch 1/2
# Processed batch 2/2
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs_global_traits.json
# Using OpenAI model: gpt-4o-mini-2024-07-18
# Configured to generate 40 captions.
# Meta Prompt: You are an AI assistant that generates creative and diverse image captions suitable for use with image generation models like DALL-E. Given a subject, provide 40 distinct, diverse and descriptive captions, considering the following global taxonomical traits when generating captions: ['Size variations (toy, miniature, standard, giant)', 'Coat types (short, long, curly, wiry)', 'Head shape (flat, rounded, elongated)', 'Ear shape (standing, floppy, semi-erect)', 'Tail types (curled, straight, docked)', 'Color patterns (solid, spotted, brindle, merle)', 'Body structure (muscular, slender, stocky)', 'Facial features (snout length, eye shape)', 'Temperament traits (playful, protective, loyal)', 'Working abilities (herding, hunting, guarding)'].
# Generating Alternative Captions: 120it [00:00, 2424.23it/s]
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Chihuahua.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Japanese_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Maltese_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Pekinese.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Shih_Tzu.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Blenheim_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\papillon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\toy_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Rhodesian_ridgeback.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Afghan_hound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\basset.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\beagle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\bloodhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\bluetick.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\black_and_tan_coonhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Walker_hound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\English_foxhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\redbone.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\borzoi.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_wolfhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Italian_greyhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\whippet.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Ibizan_hound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Norwegian_elkhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\otterhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Saluki.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Scottish_deerhound.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Weimaraner.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Staffordshire_bullterrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\American_Staffordshire_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Bedlington_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Border_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Kerry_blue_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Norfolk_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Norwich_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Yorkshire_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\wire_haired_fox_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Lakeland_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Sealyham_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Airedale.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\cairn.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Australian_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Dandie_Dinmont.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Boston_bull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\miniature_schnauzer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\giant_schnauzer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\standard_schnauzer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Scotch_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Tibetan_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\silky_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\soft_coated_wheaten_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\West_Highland_white_terrier.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Lhasa.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\flat_coated_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\curly_coated_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\golden_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Labrador_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Chesapeake_Bay_retriever.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\German_short_haired_pointer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\vizsla.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\English_setter.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_setter.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Gordon_setter.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Brittany_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\clumber.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\English_springer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Welsh_springer_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\cocker_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Sussex_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Irish_water_spaniel.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\kuvasz.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\schipperke.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\groenendael.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\malinois.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\briard.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\kelpie.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\komondor.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Old_English_sheepdog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Shetland_sheepdog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\collie.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Border_collie.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Bouvier_des_Flandres.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Rottweiler.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\German_shepherd.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Doberman.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\miniature_pinscher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Greater_Swiss_Mountain_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Bernese_mountain_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Appenzeller.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\EntleBucher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\boxer.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\bull_mastiff.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Tibetan_mastiff.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\French_bulldog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Great_Dane.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Saint_Bernard.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Eskimo_dog.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\malamute.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Siberian_husky.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\affenpinscher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\basenji.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\pug.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Leonberg.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Newfoundland.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Great_Pyrenees.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Samoyed.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Pomeranian.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\chow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\keeshond.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Brabancon_griffon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Pembroke.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Cardigan.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\toy_poodle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\miniature_poodle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\standard_poodle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\Mexican_hairless.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\dingo.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\dhole.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Stanford_dogs\40\African_hunting_dog.json
# Processed batch 1/69
# Processed batch 2/69
# Processed batch 3/69
# Processed batch 4/69
# Processed batch 5/69
# Processed batch 6/69
# Processed batch 7/69
# Processed batch 8/69
# Processed batch 9/69
# Processed batch 10/69
# Processed batch 11/69
# Processed batch 12/69
# Processed batch 13/69
# Processed batch 14/69
# Processed batch 15/69
# Processed batch 16/69
# Processed batch 17/69
# Processed batch 18/69
# Processed batch 19/69
# Processed batch 20/69
# Processed batch 21/69
# Processed batch 22/69
# Processed batch 23/69
# Processed batch 24/69
# Processed batch 25/69
# Processed batch 26/69
# Processed batch 27/69
# Processed batch 28/69
# Processed batch 29/69
# Processed batch 30/69
# Processed batch 31/69
# Processed batch 32/69
# Processed batch 33/69
# Processed batch 34/69
# Processed batch 35/69
# Processed batch 36/69
# Processed batch 37/69
# Processed batch 38/69
# Processed batch 39/69
# Processed batch 40/69
# Processed batch 41/69
# Processed batch 42/69
# Processed batch 43/69
# Processed batch 44/69
# Processed batch 45/69
# Processed batch 46/69
# Processed batch 47/69
# Processed batch 48/69
# Processed batch 49/69
# Processed batch 50/69
# Processed batch 51/69
# Processed batch 52/69
# Processed batch 53/69
# Processed batch 54/69
# Processed batch 55/69
# Processed batch 56/69
# Processed batch 57/69
# Processed batch 58/69
# Processed batch 59/69
# Processed batch 60/69
# Processed batch 61/69
# Processed batch 62/69
# Processed batch 63/69
# Processed batch 64/69
# Processed batch 65/69
# Processed batch 66/69
# Processed batch 67/69
# Processed batch 68/69
# Processed batch 69/69
# Processing Images: 100%|██████████| 322/322 [03:18<00:00,  1.62it/s]
# Class 0, Chihuahua: 0.5263158082962036, 0.1952715367078781
# Class 1, Japanese spaniel: 0.2864864766597748, 0.210490420460701
# Class 2, Maltese dog: 0.64682537317276, 0.22480270266532898
# Class 3, Pekinese: 0.6442952752113342, 0.23637105524539948
# Class 4, Shih Tzu: 0.7383177280426025, 0.21679602563381195
# Calibration Approach: Stanford_dogs
# Spearman (Pseudo vs Real Accuracy): 0.55, Spearman (Real vs Real Accuracy): 0.96
# Processed batch 1/4
# Processed batch 2/4
# Processed batch 3/4
# Processed batch 4/4
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011_global_traits.json
# Using OpenAI model: gpt-4o-mini-2024-07-18
# Configured to generate 40 captions.
# Meta Prompt: You are an AI assistant that generates creative and diverse image captions suitable for use with image generation models like DALL-E. Given a subject, provide 40 distinct, diverse and descriptive captions, considering the following global taxonomical traits when generating captions: ['Feathered body', 'Beak shape and size', 'Wing structure and length', 'Color patterns and plumage', 'Size and weight', 'Tail shape and length', 'Behavior (e.g. migratory, territorial)', 'Habitat preference (e.g. aquatic, forest, grassland)', 'Vocalizations and songs', 'Nesting habits (e.g. ground, trees, cliffs)'].
# Generating Alternative Captions: 200it [00:00, 2020.23it/s]
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Black_footed_Albatross.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Laysan_Albatross.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Sooty_Albatross.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Groove_billed_Ani.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Crested_Auklet.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Least_Auklet.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Parakeet_Auklet.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Rhinoceros_Auklet.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Brewer_Blackbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Red_winged_Blackbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Rusty_Blackbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Yellow_headed_Blackbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Bobolink.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Indigo_Bunting.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Lazuli_Bunting.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Painted_Bunting.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Cardinal.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Spotted_Catbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Gray_Catbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Yellow_breasted_Chat.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Eastern_Towhee.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Chuck_will_Widow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Brandt_Cormorant.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Red_faced_Cormorant.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pelagic_Cormorant.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Bronzed_Cowbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Shiny_Cowbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Brown_Creeper.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\American_Crow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Fish_Crow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Black_billed_Cuckoo.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Mangrove_Cuckoo.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Yellow_billed_Cuckoo.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Gray_crowned_Rosy_Finch.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Purple_Finch.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Northern_Flicker.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Acadian_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Great_Crested_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Least_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Olive_sided_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Scissor_tailed_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Vermilion_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Yellow_bellied_Flycatcher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Frigatebird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Northern_Fulmar.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Gadwall.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\American_Goldfinch.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\European_Goldfinch.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Boat_tailed_Grackle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Eared_Grebe.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Horned_Grebe.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pied_billed_Grebe.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Western_Grebe.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Blue_Grosbeak.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Evening_Grosbeak.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pine_Grosbeak.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Rose_breasted_Grosbeak.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pigeon_Guillemot.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\California_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Glaucous_winged_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Heermann_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Herring_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Ivory_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Ring_billed_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Slaty_backed_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Western_Gull.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Anna_Hummingbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Ruby_throated_Hummingbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Rufous_Hummingbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Green_Violetear.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Long_tailed_Jaeger.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pomarine_Jaeger.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Blue_Jay.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Florida_Jay.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Green_Jay.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Dark_eyed_Junco.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Tropical_Kingbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Gray_Kingbird.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Belted_Kingfisher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Green_Kingfisher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pied_Kingfisher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Ringed_Kingfisher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\White_breasted_Kingfisher.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Red_legged_Kittiwake.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Horned_Lark.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Pacific_Loon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Mallard.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Western_Meadowlark.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Hooded_Merganser.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\CUB_200_2011\40\Red_breasted_Merganser.json
# ...
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\prince_of_wales_feathers.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\purple_coneflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\red_ginger.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\rose.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\ruby-lipped_cattleya.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\siam_tulip.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\silverbush.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\snapdragon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\spear_thistle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\spring_crocus.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\stemless_gentian.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sunflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sweet_pea.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sweet_william.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sword_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\thorn_apple.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\tiger_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\toad_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\tree_mallow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\tree_poppy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\trumpet_creeper.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\wallflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\water_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\watercress.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\wild_pansy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\windflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\yellow_iris.json
# Processed batch 1/60
# Processed batch 2/60
# Processed batch 3/60
# Processed batch 4/60
# Processed batch 5/60
# Processed batch 6/60
# Processed batch 7/60
# Processed batch 8/60
# Processed batch 9/60
# Processed batch 10/60
# Processed batch 11/60
# Processed batch 12/60
# Processed batch 13/60
# Processed batch 14/60
# Processed batch 15/60
# Processed batch 16/60
# Processed batch 17/60
# Processed batch 18/60
# Processed batch 19/60
# Processed batch 20/60
# Processed batch 21/60
# Processed batch 22/60
# Processed batch 23/60
# Processed batch 24/60
# Processed batch 25/60
# Processed batch 26/60
# Processed batch 27/60
# Processed batch 28/60
# Processed batch 29/60
# Processed batch 30/60
# Processed batch 31/60
# Processed batch 32/60
# Processed batch 33/60
# Processed batch 34/60
# Processed batch 35/60
# Processed batch 36/60
# Processed batch 37/60
# Processed batch 38/60
# Processed batch 39/60
# Processed batch 40/60
# Processed batch 41/60
# Processed batch 42/60
# Processed batch 43/60
# Processed batch 44/60
# Processed batch 45/60
# Processed batch 46/60
# Processed batch 47/60
# Processed batch 48/60
# Processed batch 49/60
# Processed batch 50/60
# Processed batch 51/60
# Processed batch 52/60
# Processed batch 53/60
# Processed batch 54/60
# Processed batch 55/60
# Processed batch 56/60
# Processed batch 57/60
# Processed batch 58/60
# Processed batch 59/60
# Processed batch 60/60
# Processing Images: 100%|██████████| 51/51 [00:48<00:00,  1.05it/s]
# Class 0, alpine sea holly: 0.6363636255264282, 0.2701209783554077
# Class 1, anthurium: 0.970588207244873, 0.23110075294971466
# Class 2, artichoke: 0.9677419066429138, 0.2559536099433899
# Class 3, azalea: 0.5757575631141663, 0.23367458581924438
# Class 4, ball moss: 0.9696969985961914, 0.22230002284049988
# Class 11, black-eyed susan has NaN cm_score
# Class 26, colt's foot has NaN cm_score
# Class 32, desert-rose has NaN cm_score
# Class 44, globe-flower has NaN cm_score
# Class 47, hard-leaved pocket orchid has NaN cm_score
# Class 72, pink-yellow dahlia has NaN cm_score
# Class 79, ruby-lipped cattleya has NaN cm_score
# Class 11, black-eyed susan has NaN accuracy
# Class 26, colt's foot has NaN accuracy
# Class 32, desert-rose has NaN accuracy
# Class 44, globe-flower has NaN accuracy
# Class 47, hard-leaved pocket orchid has NaN accuracy
# Class 72, pink-yellow dahlia has NaN accuracy
# Class 79, ruby-lipped cattleya has NaN accuracy
# Processed batch 1/2
# Processed batch 2/2
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102_global_traits.json
# Using OpenAI model: gpt-4o-mini-2024-07-18
# Configured to generate 40 captions.
# Meta Prompt: You are an AI assistant that generates creative and diverse image captions suitable for use with image generation models like DALL-E. Given a subject, provide 40 distinct, diverse and descriptive captions, considering the following global taxonomical traits when generating captions: ['Petal arrangement', 'Leaf shape', 'Flower color', 'Growth habit (herbaceous vs. woody)', 'Stem structure', 'Pollination mechanism', 'Geographic distribution', 'Habitat preference (aquatic, terrestrial)', 'Fruit type (dry, fleshy)', 'Root system (fibrous vs. taproot)', 'Seasonality (annual, perennial)', 'Height and size variation', 'Reproductive structures (e.g., presence of sepals, stamens)', 'Symmetry of flowers (radial vs. bilateral)', 'Response to climate conditions', 'Association with specific insects or animals'].
# Generating Alternative Captions: 102it [00:00, 2400.04it/s]
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\alpine_sea_holly.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\anthurium.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\artichoke.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\azalea.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\ball_moss.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\balloon_flower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\barbeton_daisy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bearded_iris.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bee_balm.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bird_of_paradise.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bishop_of_llandaff.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\black-eyed_susan.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\blackberry_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\blanket_flower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bolero_deep_blue.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bougainvillea.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\bromelia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\buttercup.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\californian_poppy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\camellia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\canna_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\canterbury_bells.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\cape_flower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\carnation.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\cautleya_spicata.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\clematis.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\colt's_foot.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\columbine.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\common_dandelion.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\corn_poppy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\cyclamen.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\daffodil.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\desert-rose.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\english_marigold.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\fire_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\foxglove.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\frangipani.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\fritillary.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\garden_phlox.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\gaura.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\gazania.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\geranium.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\giant_white_arum_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\globe_thistle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\globe-flower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\grape_hyacinth.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\great_masterwort.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\hard-leaved_pocket_orchid.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\hibiscus.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\hippeastrum.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\japanese_anemone.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\king_protea.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\lenten_rose.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\lotus.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\love_in_the_mist.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\magnolia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\mallow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\marigold.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\mexican_aster.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\mexican_petunia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\monkshood.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\moon_orchid.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\morning_glory.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\orange_dahlia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\osteospermum.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\oxeye_daisy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\passion_flower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\pelargonium.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\peruvian_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\petunia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\pincushion_flower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\pink_primrose.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\pink-yellow_dahlia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\poinsettia.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\primula.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\prince_of_wales_feathers.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\purple_coneflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\red_ginger.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\rose.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\ruby-lipped_cattleya.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\siam_tulip.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\silverbush.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\snapdragon.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\spear_thistle.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\spring_crocus.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\stemless_gentian.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sunflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sweet_pea.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sweet_william.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\sword_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\thorn_apple.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\tiger_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\toad_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\tree_mallow.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\tree_poppy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\trumpet_creeper.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\wallflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\water_lily.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\watercress.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\wild_pansy.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\windflower.json
# Loaded data from cache: cache\gpt-4o-mini-2024-07-18\Flower102\40\yellow_iris.json
# Processed batch 1/60
# Processed batch 2/60
# Processed batch 3/60
# Processed batch 4/60
# Processed batch 5/60
# Processed batch 6/60
# Processed batch 7/60
# Processed batch 8/60
# Processed batch 9/60
# Processed batch 10/60
# Processed batch 11/60
# Processed batch 12/60
# Processed batch 13/60
# Processed batch 14/60
# Processed batch 15/60
# Processed batch 16/60
# Processed batch 17/60
# Processed batch 18/60
# Processed batch 19/60
# Processed batch 20/60
# Processed batch 21/60
# Processed batch 22/60
# Processed batch 23/60
# Processed batch 24/60
# Processed batch 25/60
# Processed batch 26/60
# Processed batch 27/60
# Processed batch 28/60
# Processed batch 29/60
# Processed batch 30/60
# Processed batch 31/60
# Processed batch 32/60
# Processed batch 33/60
# Processed batch 34/60
# Processed batch 35/60
# Processed batch 36/60
# Processed batch 37/60
# Processed batch 38/60
# Processed batch 39/60
# Processed batch 40/60
# Processed batch 41/60
# Processed batch 42/60
# Processed batch 43/60
# Processed batch 44/60
# Processed batch 45/60
# Processed batch 46/60
# Processed batch 47/60
# Processed batch 48/60
# Processed batch 49/60
# Processed batch 50/60
# Processed batch 51/60
# Processed batch 52/60
# Processed batch 53/60
# Processed batch 54/60
# Processed batch 55/60
# Processed batch 56/60
# Processed batch 57/60
# Processed batch 58/60
# Processed batch 59/60
# Processed batch 60/60
# Processing Images: 100%|██████████| 128/128 [01:41<00:00,  1.26it/s]
# Class 0, alpine sea holly: 0.6279069781303406, 0.26257994771003723
# Class 1, anthurium: 0.9904761910438538, 0.22898823022842407
# Class 2, artichoke: 0.7435897588729858, 0.24526415765285492
# Class 3, azalea: 0.7604166865348816, 0.23608458042144775
# Class 4, ball moss: 0.0, 0.13882482051849365
# Calibration Approach: Flower102
# Spearman (Pseudo vs Real Accuracy): 0.48, Spearman (Real vs Real Accuracy): 0.94

# %%
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ["Dataset", "Spearman (Pseudo vs Real) - Discretization Method", "Spearman (Pseudo vs Real) - Default method", "Spearman (Real vs Real) - Discretization Method", "Spearman (Real vs Real) - Default method"]
table.add_row(["Stanford_dogs", "0.59", "**0.62**", "**1.00**", "0.98"])
table.add_row(["NWPU-RESISC45", "**0.61**", "0.58", "**1.00**", "0.98"])
table.add_row(["Flower102", "**0.48**", "0.35", "**1.00**", "0.96"])
table.add_row(["CUB_200_2011", "0.73", "**0.76**", "**1.00**", "0.99"])

print(table)
# Out:
# +---------------+---------------------------------------------------+--------------------------------------------+-------------------------------------------------+------------------------------------------+
# |    Dataset    | Spearman (Pseudo vs Real) - Discretization Method | Spearman (Pseudo vs Real) - Default method | Spearman (Real vs Real) - Discretization Method | Spearman (Real vs Real) - Default method |
# +---------------+---------------------------------------------------+--------------------------------------------+-------------------------------------------------+------------------------------------------+
# | Stanford_dogs |                        0.59                       |                  **0.62**                  |                     **1.00**                    |                   0.98                   |
# | NWPU-RESISC45 |                      **0.61**                     |                    0.58                    |                     **1.00**                    |                   0.98                   |
# |   Flower102   |                      **0.48**                     |                    0.35                    |                     **1.00**                    |                   0.96                   |
# |  CUB_200_2011 |                        0.73                       |                  **0.76**                  |                     **1.00**                    |                   0.99                   |
# +---------------+---------------------------------------------------+--------------------------------------------+-------------------------------------------------+------------------------------------------+
