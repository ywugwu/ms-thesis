# %%
# post_process_results.ipynb

# Import necessary libraries
import os
import json
import yaml
import pandas as pd
import numpy as np

# Function to map dataset names to display names
def get_display_name(dataset_name):
    mapping = {
        'CUB_200_2011': 'CUB',
        'Flower102': 'Flowers',
        'wds_vtab-flowers': 'VTAB-Flowers',
        'wds_vtab-pets': 'VTAB-Pets',
        'wds_vtab-resisc45': 'VTAB-Resisc45',
        'wds_vtab-cifar100': 'VTAB-CIFAR100',
        # 'Stanford_dogs': 'Stanford Dogs',
        'wds_cars': 'Cars',
        'wds_fgvc_aircraft': 'Aircraft',
        'wds_food101': 'Food101',
        'wds_imagenetv2': 'ImageNetV2',
        'wds_objectnet': 'ObjectNet',
        'wds_sun397': 'SUN397',
        # Add other mappings as needed
    }
    return mapping.get(dataset_name, dataset_name)

# Load the configuration file
config_path = 'configs/config.yaml'
with open(config_path, 'r') as f:
    config = yaml.safe_load(f)

# Get the list of datasets and models from the config
datasets = [dataset['name'] for dataset in config['datasets']]
models = [model['name'] for model in config['models']]
gpt_model = config['gpt_model']['name']
# Initialize an empty DataFrame with datasets as index
df = pd.DataFrame()

# Directory where results are stored
results_dir = config['experiment_params']['results_dir']

# Iterate over models and datasets to populate the DataFrame
for model in models:
    model_name = model.replace('/', '_')
    model_col_prefix = get_display_name(model_name)
    for dataset in datasets:
        # Construct the filename for the result JSON
        filename = os.path.join(results_dir, f"{model_name}_{gpt_model}_{dataset}_results.json")
        # Check if the result file exists
        if os.path.exists(filename):
            with open(filename, 'r') as f:
                results = json.load(f)
            # Extract the required correlation scores
            corr_knn = results.get('corr_betweem_actual_accuracies_and_knn_probabilities')
            corr_text_consistency = results.get('corr_between_text_only_consistency_scores_and_accuracy')
            corr_classification_margin = results.get('corr_between_classification_margin_scores_and_accuracy')
            mae = results.get('mae')
            # Map dataset name to display name
            display_dataset_name = get_display_name(dataset)
            # Add the scores to the DataFrame
            df.loc[display_dataset_name, f'{model_col_prefix} Corr(KNN)'] = corr_knn
            df.loc[display_dataset_name, f'{model_col_prefix} Corr(Text Consistency)'] = corr_text_consistency
            df.loc[display_dataset_name, f'{model_col_prefix} Corr(Classification Margin)'] = corr_classification_margin
            df.loc[display_dataset_name, f'{model_col_prefix} (MAE)'] = mae
        else:
            print(f"Result file {filename} not found.")

# Reorder the DataFrame to match your specified dataset order
specified_order = [
    'CUB',
    'Cars',
    'Aircraft',
    'Food101',
    'ImageNetV2',
    'ObjectNet',
    'SUN397',
    'VTAB-CIFAR100',
    'Flowers',
    'VTAB-Pets',
    'VTAB-Resisc45',
    'Stanford Dogs'
]
df = df.reindex(specified_order)

# Display the DataFrame with rounded values
df_rounded = df.round(3)
df_rounded

# Save the DataFrame to a CSV file (optional)
output_csv = 'correlation_results.csv'
df_rounded.to_csv(output_csv)
print(f"Results saved to {output_csv}")
# Out:
# Results saved to correlation_results.csv

# %%
df_rounded
# Out:
#                openai_clip-vit-large-patch14 Corr(KNN)  \
# CUB                                              0.393
# Cars                                             0.452
# Aircraft                                         0.403
# Food101                                          0.444
# ImageNetV2                                       0.307
# ObjectNet                                          NaN
# SUN397                                             NaN
# VTAB-CIFAR100                                    0.014
# Flowers                                          0.163
# VTAB-Pets                                        0.305
# VTAB-Resisc45                                    0.344
# Stanford Dogs                                      NaN
#
#                openai_clip-vit-large-patch14 Corr(Text Consistency)  \
# CUB                                                        0.416
# Cars                                                       0.407
# Aircraft                                                   0.405
# Food101                                                    0.403
# ImageNetV2                                                 0.238
# ObjectNet                                                    NaN
# SUN397                                                       NaN
# VTAB-CIFAR100                                             -0.144
# Flowers                                                    0.192
# VTAB-Pets                                                  0.221
# VTAB-Resisc45                                              0.571
# Stanford Dogs                                                NaN
#
#                openai_clip-vit-large-patch14 Corr(Classification Margin)  \
# CUB                                                        0.423
# Cars                                                       0.329
# Aircraft                                                   0.418
# Food101                                                    0.421
# ImageNetV2                                                 0.310
# ObjectNet                                                    NaN
# SUN397                                                       NaN
# VTAB-CIFAR100                                             -0.107
# Flowers                                                    0.193
# VTAB-Pets                                                  0.256
# VTAB-Resisc45                                              0.511
# Stanford Dogs                                                NaN
#
#                openai_clip-vit-large-patch14 (MAE)  \
# CUB                                          0.269
# Cars                                         0.200
# Aircraft                                     0.254
# Food101                                      0.217
# ImageNetV2                                   0.214
# ObjectNet                                      NaN
# SUN397                                         NaN
# VTAB-CIFAR100                                0.239
# Flowers                                      0.228
# VTAB-Pets                                    0.118
# VTAB-Resisc45                                0.269
# Stanford Dogs                                  NaN
#
#                google_siglip-base-patch16-224 Corr(KNN)  \
# CUB                                               0.496
# Cars                                              0.372
# Aircraft                                          0.514
# Food101                                           0.193
# ImageNetV2                                        0.191
# ObjectNet                                           NaN
# SUN397                                              NaN
# VTAB-CIFAR100                                    -0.212
# Flowers                                          -0.006
# VTAB-Pets                                         0.057
# VTAB-Resisc45                                     0.005
# Stanford Dogs                                       NaN
#
#                google_siglip-base-patch16-224 Corr(Text Consistency)  \
# CUB                                                        0.422
# Cars                                                       0.277
# Aircraft                                                   0.546
# Food101                                                    0.127
# ImageNetV2                                                 0.114
# ObjectNet                                                    NaN
# SUN397                                                       NaN
# VTAB-CIFAR100                                             -0.055
# Flowers                                                   -0.088
# VTAB-Pets                                                  0.091
# VTAB-Resisc45                                              0.184
# Stanford Dogs                                                NaN
#
#                google_siglip-base-patch16-224 Corr(Classification Margin)  \
# CUB                                                        0.475
# Cars                                                       0.274
# Aircraft                                                   0.632
# Food101                                                    0.109
# ImageNetV2                                                 0.179
# ObjectNet                                                    NaN
# SUN397                                                       NaN
# VTAB-CIFAR100                                             -0.124
# Flowers                                                   -0.036
# VTAB-Pets                                                 -0.016
# VTAB-Resisc45                                              0.143
# Stanford Dogs                                                NaN
#
#                google_siglip-base-patch16-224 (MAE)  \
# CUB                                           0.181
# Cars                                          0.107
# Aircraft                                      0.229
# Food101                                       0.173
# ImageNetV2                                    0.227
# ObjectNet                                       NaN
# SUN397                                          NaN
# VTAB-CIFAR100                                 0.261
# Flowers                                       0.289
# VTAB-Pets                                     0.264
# VTAB-Resisc45                                 0.342
# Stanford Dogs                                   NaN
#
#                facebook_flava-full Corr(KNN)  \
# CUB                                    0.439
# Cars                                   0.540
# Aircraft                               0.261
# Food101                               -0.015
# ImageNetV2                             0.304
# ObjectNet                                NaN
# SUN397                                   NaN
# VTAB-CIFAR100                          0.128
# Flowers                                0.372
# VTAB-Pets                             -0.045
# VTAB-Resisc45                         -0.044
# Stanford Dogs                            NaN
#
#                facebook_flava-full Corr(Text Consistency)  \
# CUB                                                 0.482
# Cars                                                0.552
# Aircraft                                            0.337
# Food101                                            -0.076
# ImageNetV2                                          0.085
# ObjectNet                                             NaN
# SUN397                                                NaN
# VTAB-CIFAR100                                       0.085
# Flowers                                             0.330
# VTAB-Pets                                          -0.072
# VTAB-Resisc45                                       0.045
# Stanford Dogs                                         NaN
#
#                facebook_flava-full Corr(Classification Margin)  \
# CUB                                                      0.464
# Cars                                                     0.585
# Aircraft                                                 0.329
# Food101                                                 -0.116
# ImageNetV2                                               0.146
# ObjectNet                                                  NaN
# SUN397                                                     NaN
# VTAB-CIFAR100                                            0.153
# Flowers                                                  0.276
# VTAB-Pets                                               -0.222
# VTAB-Resisc45                                            0.117
# Stanford Dogs                                              NaN
#
#                facebook_flava-full (MAE)
# CUB                                0.266
# Cars                               0.266
# Aircraft                           0.151
# Food101                            0.181
# ImageNetV2                         0.263
# ObjectNet                            NaN
# SUN397                               NaN
# VTAB-CIFAR100                      0.201
# Flowers                            0.289
# VTAB-Pets                          0.220
# VTAB-Resisc45                      0.313
# Stanford Dogs                        NaN

# %%
results
# Out:
# {'corr_between_actual_and_pseudo_accuracies': None,
#  'corr_betweem_actual_accuracies_and_knn_probabilities': -0.04389375903155421,
#  'mae': 0.3128984349878419,
#  'mase_baseline': 0.2924679001372217,
#  'overall_accuracy': 0.4361904761904762,
#  'corr_between_text_only_consistency_scores_and_accuracy': 0.04467138917461374,
#  'corr_between_classification_margin_scores_and_accuracy': 0.11721298132984932}
